# %% [markdown]
# # Automated CAD-to-CFD Workflow: Internal Pipe Flow
#
# **Author:** Mohammad Afshar
# **Date:** January 2026
# **Tools:** CadQuery (Python 3.13.11), OpenFOAM v13, ParaView, vs code, pc with wsl
#
# ## 1. Project Overview
# This notebook demonstrates an automated engineering workflow for fluid dynamics. Instead of manually drawing geometry in a GUI, I use **Python** to parametrically generate a fluid domain. This geometry is then automatically processed and exported for Computational Fluid Dynamics (CFD) analysis in OpenFOAM.
#
# ### Key Objectives:
# 1.  **Parametric Design:** Generate a pipe geometry where diameter and length can be changed via variables.
# 2.  **Automated Selection:** Programmatically identify and separate `Inlet`, `Outlet`, and `Wall` boundaries.
# 3.  **Physics Verification:** Simulate Laminar Flow and verify the fully developed velocity profile.

# %% [markdown]
# ## 2. Theoretical Background
# To ensure a stable Laminar flow simulation, we calculate the Reynolds Number ($Re$) to size our pipe and velocity correctly.
#
# $$Re = \frac{\rho v D}{\mu}$$
#
#
# * **Fluid:** Water ($\nu \approx 1 \times 10^{-6} m^2/s$)
# * **Diameter:** $50.8 mm$
#
# $$Re = \frac{v \times 0.0508}{10^{-6}} = 2000$$
#
# * **Target Velocity:** $0.04 m/s$
#
# At this low velocity, we expect a parabolic velocity profile to develop fully within the $1000 mm$ pipe length.

# %% [markdown]
# ### Step 1: Initialize OpenFOAM Environment
# We start by copying the standard `motorBike` tutorial. This provides us with the necessary `snappyHexMesh` configuration files, which we will later modify for our pipe.
#
# * **Source:** `/opt/openfoam13/.../motorBike`
# * **Destination:** `$FOAM_RUN/pipeProject`

# %%
# %%bash
# cp -r /opt/openfoam13/tutorials/incompressibleFluid/motorBike/motorBike $FOAM_RUN/pipeProject
# cd $FOAM_RUN/pipeProject

# %% [markdown]
# ### Step 2: Parametric Geometry Generation
# We use **CadQuery** to generate the fluid domain programmatically.
#
# Instead of exporting the entire object as one STL, we identify and export the boundaries (`inlet`, `outlet`, `walls`) separately.
#
# This allows OpenFOAM to apply different physics conditions (e.g., *Velocity Inlet* vs *No-Slip Wall*) to each surface automatically.
#
# * **Fluid Domain:** Cylinder ($L=1000mm, r=25.4mm$)
# * **Export Path:** `./constant/geometry/` (Standard for OpenFOAM v13)

# %%
radius = 0.0254
length = 1

# %% [markdown]
# #### 1.importing related lib

# %%
import os
import cadquery as cq

# %% [markdown]
# #### 2.Creating the geometry

# %% [markdown]
# for simplicity we are doing each operation line by line.

# %%
#select a workplane on a plane
fluid_domain = cq.Workplane("YZ")
#sketch a circle on that workplane
fluid_domain= fluid_domain.circle(radius)
#extrude the circle along the X axis
fluid_domain= fluid_domain.extrude(length)

# %% [markdown]
# at this stage you can visualize your model in vs code by using the following

# %%
from ocp_vscode import show, set_port
set_port(3939)
show(fluid_domain)
# Out:
# UserWarning: The viewer doesn't seem to run: [Errno 111] Connection refused
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/cq/lib/python3.13/site-packages/ocp_vscode/config.py:481, in status(port, viewer, debug)
#     480 if response.get("collapse") is not None:
# --> 481     response["collapse"] = COLLAPSE_REVERSE_MAPPING[response["collapse"]]
#     482 return dict(sorted(response.items()))
#
# KeyError: 'none'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/miniforge3/envs/cq/lib/python3.13/site-packages/ocp_vscode/config.py:535, in combined_config(port, viewer)
#     534     wspace_config = workspace_config(port=port, viewer=viewer)
# --> 535     wspace_status = status(port=port, viewer=viewer)
#     537 except Exception as ex:
#
# File ~/miniforge3/envs/cq/lib/python3.13/site-packages/ocp_vscode/config.py:485, in status(port, viewer, debug)
#     484 except Exception as ex:
# --> 485     raise RuntimeError(
#     486         "Cannot access viewer status. Is the viewer running?\n" + str(ex.args)
#     487     ) from ex
#
# RuntimeError: Cannot access viewer status. Is the viewer running?
# ('none',)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[37], line 3
#       1 from ocp_vscode import show, set_port
#       2 set_port(3939)
# ----> 3 show(fluid_domain)
#
# File ~/miniforge3/envs/cq/lib/python3.13/site-packages/ocp_vscode/show.py:565, in show(names, colors, alphas, port, progress, glass, tools, tree_width, axes, axes0, grid, ortho, transparent, default_opacity, black_edges, orbit_control, control, collapse, explode, ticks, center_grid, grid_font_size, up, tab, zoom, position, quaternion, target, reset_camera, clip_slider_0, clip_slider_1, clip_slider_2, clip_normal_0, clip_normal_1, clip_normal_2, clip_intersection, clip_planes, clip_object_colors, pan_speed, rotate_speed, zoom_speed, deviation, angular_tolerance, edge_accuracy, default_color, default_edgecolor, default_facecolor, default_thickedgecolor, default_vertexcolor, ambient_intensity, direct_intensity, metalness, roughness, render_edges, render_normals, render_mates, render_joints, show_parent, show_sketch_local, helper_scale, mate_scale, debug, timeit, _force_in_debug, *cad_objs)
#     401 def show(
#     402     *cad_objs,
#     403     names=None,
#    (...)    467 ):
#     468     # pylint: disable=line-too-long
#     469     """Show CAD objects in Visual Studio Code
#     470     Parameters
#     471         cad_objs:                All cad objects that should be shown as positional parameters
#    (...)    562         timeit:                  Show timing information from level 0-3 (default=False)
#     563     """
# --> 565     return _show(*cad_objs, **none_filter(locals(), ["cad_objs"]))
#
# File ~/miniforge3/envs/cq/lib/python3.13/site-packages/ocp_vscode/show.py:658, in _show(*cad_objs, **kwargs)
#     655 progress = Progress([] if progress is None else [c for c in progress])
#     657 with Timer(timeit, "", "overall"):
# --> 658     t, mapping = _convert(
#     659         *cad_objs,
#     660         names=names,
#     661         colors=colors,
#     662         alphas=alphas,
#     663         progress=progress,
#     664         **kwargs,
#     665     )
#     667     if not _force_in_debug:
#     668         LAST_CALL = "show"
#
# File ~/miniforge3/envs/cq/lib/python3.13/site-packages/ocp_vscode/show.py:331, in _convert(names, colors, alphas, progress, *cad_objs, **kwargs)
#     328 if progress is None:
#     329     progress = Progress([c for c in "-+c"])
# --> 331 instances, shapes, config, count_shapes, mapping = _tessellate(
#     332     *cad_objs,
#     333     names=names,
#     334     colors=colors,
#     335     alphas=alphas,
#     336     progress=progress,
#     337     **kwargs,
#     338 )
#     340 if config.get("dark") is not None:
#     341     config["theme"] = "dark"
#
# File ~/miniforge3/envs/cq/lib/python3.13/site-packages/ocp_vscode/show.py:110, in _tessellate(names, colors, alphas, progress, *cad_objs, **kwargs)
#     107 viewer = kwargs.get("viewer")
#     108 port = kwargs.get("port")
# --> 110 conf = combined_config(viewer=viewer, port=port)
#     111 if conf.get("_splash"):
#     112     if conf.get("reset_camera") not in [
#     113         Camera.ISO,
#     114         Camera.LEFT,
#    (...)    119         Camera.BOTTOM,
#     120     ]:
#
# File ~/miniforge3/envs/cq/lib/python3.13/site-packages/ocp_vscode/config.py:538, in combined_config(port, viewer)
#     535     wspace_status = status(port=port, viewer=viewer)
#     537 except Exception as ex:
# --> 538     raise RuntimeError(
#     539         "Cannot access viewer config. Is the viewer running?\n" + str(ex.args)
#     540     ) from ex
#     542 use_status = not wspace_config.get("_splash", False)
#     544 wspace_config.update(DEFAULTS)
#
# RuntimeError: Cannot access viewer config. Is the viewer running?
# ("Cannot access viewer status. Is the viewer running?\n('none',)",)

# %% [markdown]
# ### 2. Select the Boundaries
# We identify faces based on their position relative to the axes.
#
# INLET: The face at the "bottom" of the extrude (negative X)
#
# OUTLET: The face at the "top" of the extrude (positive X)
#
# WALLS: The rounded face parallel to the X axis
#
# note: "|X" selector means "faces parallel to X axis" and not |x mean all faces except those parallel to X axis because we have a cylinder

# %%
inlet_face = fluid_domain.faces("<X")

outlet_face = fluid_domain.faces(">X")

wall_face = fluid_domain.faces("not |X")
# Out:
# PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
# PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'

# %% [markdown]
# ### 3. Export separate STL files
# OpenFOAM will use these filenames as the patch names if you load them individually

# %% [markdown]
# just  some simple variables so the directories of the files or somewhat automated

# %%
rawinletpath = "$FOAM_RUN/pipeProject/constant/geometry/inlet.stl"
rawoutletpath = "$FOAM_RUN/pipeProject/constant/geometry/outlet.stl"
rawwallpath = "$FOAM_RUN/pipeProject/constant/geometry/walls.stl"

# Expand the variable to the actual system path

fullinletpath = os.path.expandvars(rawinletpath)
fulloutletpath = os.path.expandvars(rawoutletpath)
fullwallpath = os.path.expandvars(rawwallpath)

# %% [markdown]
# exporting the faces to stl files to the related directories

# %%
inlet_face.export(fullinletpath)
outlet_face.export(fulloutletpath)
wall_face.export(fullwallpath)

# %% [markdown]
# Openfoam
#
# %%bash
#
# cd $FOAM_RUN/pipeProject
#
# is just that we are in the correct directory because the jupyter notebook launches bash in the home directory and not in the specific folder that we need.
#
# cat << 'EOF' > system/blockMeshDict
#
# and this is so that we can write some text and rewrite it to a specific document

# %% [markdown]
# OpenFOAM's `snappyHexMesh` is a "cut-cell" mesher. It does not generate a mesh from nothing; instead, it requires a background grid which it then carves into the shape of our geometry.
#
# We modify `system/blockMeshDict` to create a bounding box slightly larger than our pipe.
# We add a **1mm buffer** on all sides to ensuring the fluid domain is fully captured within the meshable area.

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# cat << 'EOF' > system/blockMeshDict
# /*--------------------------------*- C++ -*----------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  v2206                                 |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       dictionary;
#     object      blockMeshDict;
# }
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
#
# scale   1;
#
# vertices
# (
#     (-0.1 -0.03 -0.03)
#     (1.1 -0.03 -0.03)
#     (1.1  0.03 -0.03)
#     (-0.01  0.03 -0.03)
#     (-0.01 -0.03  0.03)
#     (1.1 -0.03  0.03)
#     (1.1  0.03  0.03)
#     (-0.01  0.03  0.03)
# );
#
# blocks
# (
#     hex (0 1 2 3 4 5 6 7) (100 10 10) simpleGrading (1 1 1)
# );
#
# edges
# (
# );
#
# boundary
# (
#     bounding
#     {
#         type patch;
#         faces
#         (
#             (0 1 5 4)
#             (1 2 6 5)
#             (2 3 7 6)
#             (3 0 4 7)
#             (0 3 2 1)
#             (4 5 6 7)
#         );
#     }
# );
#
# // ************************************************************************* //
# EOF

# %% [markdown]
# This dictionary controls how the mesh is carved.
#
# 1.  **Geometry Import:** We linked our three STL files (`inlet`, `outlet`, `walls`) and assigned them specific names.
#     * *Note:* OpenFOAM v13 requires the explicit `file` keyword.
# 2.  **Refinement Surfaces:** We told the mesher to refine near these surfaces to capture the curvature of the pipe accurately.
# 3.  **Location In Mesh:** We set the coordinate `(0.5 0 0)` as the "seed point."
#     * **important:** This point must be **inside** the fluid. `snappyHexMesh` keeps the region containing this point and deletes everything else.

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# cat << 'EOF' > system/snappyHexMeshDict
# /*--------------------------------*- C++ -*----------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  v2206                                 |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       dictionary;
#     object      snappyHexMeshDict;
# }
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
#
# castellatedMesh true;
# snap            true;
# addLayers       false;
#
# geometry
# {
#     inlet.stl
#     {
#         type triSurfaceMesh;
#         file "inlet.stl";      // Explicit file definition required in v13
#         name inlet;
#     }
#     outlet.stl
#     {
#         type triSurfaceMesh;
#         file "outlet.stl";
#         name outlet;
#     }
#     walls.stl
#     {
#         type triSurfaceMesh;
#         file "walls.stl";
#         name walls;
#     }
# }
#
# castellatedMeshControls
# {
#     maxLocalCells 100000;
#     maxGlobalCells 2000000;
#     minRefinementCells 100;
#     maxLoadUnbalance 0.10;
#     nCellsBetweenLevels 3;
#
#     features
#     (
#     );
#
#     refinementSurfaces
#     {
#         inlet
#         {
#             level (2 2);
#             patchInfo { type patch; }
#         }
#         outlet
#         {
#             level (2 2);
#             patchInfo { type patch; }
#         }
#         walls
#         {
#             level (2 2);
#             patchInfo { type wall; }
#         }
#     }
#
#     resolveFeatureAngle 30;
#     locationInMesh (0.5 0 0);
#     allowFreeStandingZoneFaces true;
# }
#
# snapControls
# {
#     nSmoothPatch 3;
#     tolerance 2.0;
#     nSolveIter 30;
#     nRelaxIter 5;
#     nFeatureSnapIter 10;
#     implicitFeatureSnap false;
#     explicitFeatureSnap true;
#     multiRegionFeatureSnap false;
# }
#
# addLayersControls
# {
#     relativeSizes true;
#     layers
#     {
#         walls
#         {
#             nSurfaceLayers 3;
#         }
#     }
#     expansionRatio 1.0;
#     finalLayerThickness 0.3;
#     minThickness 0.1;
#     nGrow 0;
#     featureAngle 60;
#     slipFeatureAngle 30;
#     nRelaxIter 3;
#     nSmoothSurfaceNormals 1;
#     nSmoothNormals 3;
#     nSmoothThickness 10;
#     maxFaceThicknessRatio 0.5;
#     maxThicknessToMedialRatio 0.3;
#     minMedianAxisAngle 90;
#     nBufferCellsNoExtrude 0;
#     nLayerIter 50;
# }
#
# meshQualityControls
# {
#     maxNonOrtho 65;
#     maxBoundarySkewness 20;
#     maxInternalSkewness 4;
#     maxConcave 80;
#     minVol 1e-13;
#     minTetQuality 1e-30;
#     minArea -1;
#     minTwist 0.02;
#     minDeterminant 0.001;
#     minFaceWeight 0.02;
#     minVolRatio 0.01;
#     minTriangleTwist -1;
#     nSmoothScale 4;
#     errorReduction 0.75;
# }
#
# mergeTolerance 1e-6;
#
# // ************************************************************************* //
# EOF

# %% [markdown]
# ### Mesh Controls
# we tweak the mesh settings in two specific files.
#
# #### 1. Global Resolution (`system/blockMeshDict`)
# * Look for: `blocks ( hex ... (20 10 10) ... )`
# (x y z) number of cells
# increase/decrease the numbers
#
# #### 2. Local Refinement (`system/snappyHexMeshDict`)
#
# (min max) refinement layers
# * Look for: `level (2 2);` inside `refinementSurfaces`.
# * **The Logic:**
#     * **Level 0:** Base size (same as blockMesh).
#     * **Level 1:** Split cell in half (2x detail).
#     * **Level 2:** Split cell again (4x detail).
# * **Tweak:** Change `(2 2)` to `(3 3)` for very smooth curved walls, or `(1 1)` for a rough, fast check.
#
# #### 3. Boundary Layers (Advanced)
# * Look for: `addLayers false;` at the top of `snappyHexMeshDict`.
# * **Tweak:** Set to `true` to insert thin "prism layers" along the walls. This is critical for accurate friction calculations in Turbulent flow, but optional for this simple Laminar case.

# %% [markdown]
# run the meshing tools

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# blockMesh
# snappyHexMesh -overwrite
# Out:
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  13
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 13-cde978a97c93
# Exec   : blockMesh
# Date   : Jan 27 2026
# Time   : 20:41:42
# Host   : "Radin"
# PID    : 19059
# I/O    : uncollated
# Case   : /home/radin/OpenFOAM/radin-13/run/pipeProject
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Reading "blockMeshDict"
#
# Creating block mesh from
#     "system/blockMeshDict"
# Creating block edges
# No non-planar block faces defined
# Creating topology blocks
# Creating topology patches
#
# Creating block mesh topology
#
# Basic statistics
#     Number of internal faces : 0
#     Number of boundary faces : 6
#     Number of defined boundary faces : 6
#     Number of undefined boundary faces : 0
#
# Checking topology
# Creating block offsets
# Creating merge list .
#
# Creating polyMesh from blockMesh
# Creating patches
# Creating cells
# Creating points with scale 1
#     Block 0 cell size :
#         i : 0.012 .. 0.012 0.01191 .. 0.01191 0.01191 .. 0.01191 0.011829 .. 0.011829
#         j : 0.0108167 .. 0.0108167 0.0107419 .. 0.0107419 0.0100802 .. 0.0100802 0.0100152 .. 0.0100152
#         k : 0.0108167 0.0107419 .. 0.0107419 0.0100802 .. 0.0100802 0.0100152 .. 0.0100152
#
# No patch pairs to merge
#
# Writing polyMesh
# ----------------
# Mesh Information
# ----------------
#   boundingBox: (-0.1 -0.03 -0.03) (1.1 0.03 0.03)
#   nPoints: 12221
#   nCells: 10000
#   nFaces: 32100
#   nInternalFaces: 27900
# ----------------
# Patches
# ----------------
#   patch 0 (start: 27900 size: 4200) name: bounding
#
# End
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  13
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 13-cde978a97c93
# Exec   : snappyHexMesh -overwrite
# Date   : Jan 27 2026
# Time   : 20:41:42
# Host   : "Radin"
# PID    : 19060
# I/O    : uncollated
# Case   : /home/radin/OpenFOAM/radin-13/run/pipeProject
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0
#
# Read mesh in = 0.003592 s
# Deprecated option 'overwrite' specified, this is now the default behaviour
#
# Reading "snappyHexMeshDict"
#
#
# Overall mesh bounding box  : (-0.1 -0.03 -0.03) (1.1 0.03 0.03)
# Relative tolerance         : 1e-06
# Absolute matching distance : 1.203e-06
#
# Reading refinement surfaces...
# Read refinement surfaces in = 0.000733 s
#
# Reading refinement regions...
# Read refinement regions in = 4.5e-05 s
#
# Reading features...
# Read features in = 1.6e-05 s
#
#
# Determining initial surface intersections
# -----------------------------------------
#
# Edge intersection testing:
#     Number of edges             : 32100
#     Number of edges to retest   : 32100
#     Number of intersected edges : 2968
# Calculated surface intersections in = 0.026216 s
#
# Initial mesh : cells:10000  faces:32100  points:12221
# Cells per refinement level:
#     0	10000
#
# Adding patches for surface regions
# ----------------------------------
#
# Patch Type                Region
# ----- ----                ------
# inlet:
#
# 1     patch               inlet
#
# outlet:
#
# 2     patch               outlet
#
# walls:
#
# 3     wall                walls
#
# Added patches in = 0.001009 s
#
# Selecting distributor none
# Cell selection insidePoints: 1((0.5 0 0))
#
# Refinement phase
# ----------------
#
# Found point (0.5 0 0) in cell 4447 on processor 0
#
# Surface refinement iteration 0
# ------------------------------
#
# Marked for refinement due to surface intersection          : 4054 cells.
# Determined cells to refine in = 0.022912 s
# Selected for refinement : 4054 cells (out of 10000)
# Edge intersection testing:
#     Number of edges             : 126138
#     Number of edges to retest   : 116689
#     Number of intersected edges : 11920
# Refined mesh in = 0.095795 s
# After refinement surface refinement iteration 0 : cells:38378  faces:126138  points:49516
# Cells per refinement level:
#     0	5946
#     1	32432
#
# Surface refinement iteration 1
# ------------------------------
#
# Marked for refinement due to surface intersection          : 17021 cells.
# Determined cells to refine in = 0.003 s
# Selected for refinement : 18165 cells (out of 38378)
# Edge intersection testing:
#     Number of edges             : 543417
#     Number of edges to retest   : 530448
#     Number of intersected edges : 50510
# Refined mesh in = 0.458055 s
# After refinement surface refinement iteration 1 : cells:165533  faces:543417  points:212500
# Cells per refinement level:
#     0	4784
#     1	24725
#     2	136024
#
# Surface refinement iteration 2
# ------------------------------
#
# Marked for refinement due to surface intersection          : 60 cells.
# Determined cells to refine in = 0.014151 s
# Selected for refinement : 74 cells (out of 165533)
# Stopping refining since too few cells selected.
#
#
# Removing mesh beyond surface intersections
# ------------------------------------------
#
# Selecting all cells in regions containing any of the points in 1((0.5 0 0))
# Selected: 141491 cells.
# Edge intersection testing:
#     Number of edges             : 496126
#     Number of edges to retest   : 59849
#     Number of intersected edges : 50510
#
# Shell refinement iteration 0
# ----------------------------
#
# Marked for refinement due to distance to explicit features : 0 cells.
# Marked for refinement due to refinement shells             : 0 cells.
# Determined cells to refine in = 1.26868 s
# Selected for internal refinement : 12117 cells (out of 141491)
# Edge intersection testing:
#     Number of edges             : 753040
#     Number of edges to retest   : 543304
#     Number of intersected edges : 50532
# Refined mesh in = 0.524394 s
# After refinement shell refinement iteration 0 : cells:226310  faces:753040  points:298329
# Cells per refinement level:
#     0	2907
#     1	19529
#     2	203874
#
# Shell refinement iteration 1
# ----------------------------
#
# Marked for refinement due to distance to explicit features : 0 cells.
# Marked for refinement due to refinement shells             : 0 cells.
# Determined cells to refine in = 0.090929 s
# Selected for internal refinement : 872 cells (out of 226310)
# Edge intersection testing:
#     Number of edges             : 771379
#     Number of edges to retest   : 61180
#     Number of intersected edges : 50532
# Refined mesh in = 0.393006 s
# After refinement shell refinement iteration 1 : cells:232414  faces:771379  points:304461
# Cells per refinement level:
#     0	2574
#     1	21654
#     2	208186
#
# Shell refinement iteration 2
# ----------------------------
#
# Marked for refinement due to distance to explicit features : 0 cells.
# Marked for refinement due to refinement shells             : 0 cells.
# Determined cells to refine in = 0.094781 s
# Selected for internal refinement : 20 cells (out of 232414)
# Stopping refining since too few cells selected.
#
#
# Dangling coarse cells refinement iteration 0
# --------------------------------------------
#
# Determined cells to refine in = 0.004437 s
# Selected for refinement : 7 cells (out of 232414)
# Edge intersection testing:
#     Number of edges             : 771484
#     Number of edges to retest   : 829
#     Number of intersected edges : 50532
# Refined mesh in = 0.338928 s
# After refinement coarse cell refinement iteration 0 : cells:232463  faces:771484  points:304475
# Cells per refinement level:
#     0	2574
#     1	21647
#     2	208242
#
# Dangling coarse cells refinement iteration 1
# --------------------------------------------
#
# Determined cells to refine in = 0.005516 s
# Selected for refinement : 0 cells (out of 232463)
# Stopping refining since too few cells selected.
#
#
# Dangling coarse cells refinement iteration 0
# --------------------------------------------
#
# Determined cells to refine in = 0.003827 s
# Selected for refinement : 0 cells (out of 232463)
# Stopping refining since too few cells selected.
#
#
# Splitting mesh at surface intersections
# ---------------------------------------
#
# Introducing baffles for 50532 faces that are intersected by the surface.
#
# Edge intersection testing:
#     Number of edges             : 822016
#     Number of edges to retest   : 310292
#     Number of intersected edges : 99859
# Created baffles in = 0.409756 s
#
#
# After introducing baffles : cells:232463  faces:822016  points:304475
# Cells per refinement level:
#     0	2574
#     1	21647
#     2	208242
#
# Introducing baffles to block off problem cells
# ----------------------------------------------
#
# markFacesOnProblemCells : marked 64568 additional internal faces to be converted into baffles.
# Analyzed problem cells in = 0.219728 s
#
#
# Introducing baffles to delete problem cells.
#
# Edge intersection testing:
#     Number of edges             : 886584
#     Number of edges to retest   : 214530
#     Number of intersected edges : 105957
# Created baffles in = 0.406792 s
#
#
# After introducing baffles : cells:232463  faces:886584  points:304475
# Cells per refinement level:
#     0	2574
#     1	21647
#     2	208242
#
# Remove unreachable sections of mesh
# -----------------------------------
#
# Keeping all cells in regions containing any point in 1((0.5 0 0))
# Selected for keeping : 136659 cells.
# Edge intersection testing:
#     Number of edges             : 453882
#     Number of edges to retest   : 0
#     Number of intersected edges : 49842
# Split mesh in = 1.68744 s
#
#
# After subsetting : cells:136659  faces:453882  points:180697
# Cells per refinement level:
#     0	1052
#     1	15408
#     2	120199
#
# Handling cells with snap problems
# ---------------------------------
#
# Introducing baffles for 49842 faces that are intersected by the surface.
#
# Edge intersection testing:
#     Number of edges             : 453882
#     Number of edges to retest   : 150144
#     Number of intersected edges : 49842
# Created baffles in = 0.205705 s
#
#
# After introducing baffles : cells:136659  faces:453882  points:180697
# Cells per refinement level:
#     0	1052
#     1	15408
#     2	120199
#
# Introducing baffles to block off problem cells
# ----------------------------------------------
#
# markFacesOnProblemCells : marked 0 additional internal faces to be converted into baffles.
# Analyzed problem cells in = 0.12659 s
#
#
# Introducing baffles to delete problem cells.
#
# Edge intersection testing:
#     Number of edges             : 453882
#     Number of edges to retest   : 0
#     Number of intersected edges : 49842
# Created baffles in = 0.147807 s
#
#
# After introducing baffles : cells:136659  faces:453882  points:180697
# Cells per refinement level:
#     0	1052
#     1	15408
#     2	120199
#
# Remove unreachable sections of mesh
# -----------------------------------
#
# Split mesh in = 0.728881 s
#
#
# After subsetting : cells:136659  faces:453882  points:180697
# Cells per refinement level:
#     0	1052
#     1	15408
#     2	120199
#
# Merge free-standing baffles
# ---------------------------
#
# freeStandingBaffles : detected 0 free-standing baffles out of 0
#
# Detected free-standing baffles : 0
# Merged free-standing baffles in = 0.043474 s
#
#
# dupNonManifoldPoints : Found : 0 non-manifold points (out of 180697)
# Edge intersection testing:
#     Number of edges             : 453882
#     Number of edges to retest   : 0
#     Number of intersected edges : 49842
# Detected unsplittable baffles : 0
#
# Merge refined boundary faces
# ----------------------------
#
# Merging 4 sets of faces.
#
# Edge intersection testing:
#     Number of edges             : 453878
#     Number of edges to retest   : 20
#     Number of intersected edges : 49838
#
# Undo iteration 0
# ----------------
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 9
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Masters that need to be restored:0
#
# Merging all points on surface that
# - are used by only two boundary faces and
# - make an angle with a cosine of more than 0.707107.
#
# Removing 4 straight edge points ...
#
# Edge intersection testing:
#     Number of edges             : 453878
#     Number of edges to retest   : 20
#     Number of intersected edges : 49838
#
# Undo iteration 0
# ----------------
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 9
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Detected 0 error faces on boundaries that have been merged. These will be restored to their original faces.
#
# Detected 9 error faces in mesh. Restoring neighbours of faces in error.
#
# Edge intersection testing:
#     Number of edges             : 453878
#     Number of edges to retest   : 659
#     Number of intersected edges : 49838
# Refined mesh : cells:136659  faces:453878  points:180693
# Cells per refinement level:
#     0	1052
#     1	15408
#     2	120199
# Writing mesh to time constant
# Wrote mesh in = 1.11014 s.
# Mesh refined in = 8.40453 s.
#
# Morphing phase
# --------------
#
#
# Snapping to features in 10 iterations ...
# Constructing mesh displacer ...
# Using mesh parameters
# {
#     maxNonOrtho     65;
#     maxBoundarySkewness 20;
#     maxInternalSkewness 4;
#     maxConcave      80;
#     minVol          1e-13;
#     minTetQuality   1e-30;
#     minArea         -1;
#     minTwist        0.02;
#     minDeterminant  0.001;
#     minFaceWeight   0.02;
#     minVolRatio     0.01;
#     minTriangleTwist -1;
#     nSmoothScale    4;
#     errorReduction  0.75;
# }
#
#
# Checking initial mesh ...
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 9
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Detected 9 illegal faces (concave, zero area or negative cell pyramid volume)
# Checked initial mesh in = 0.2431 s
#
#
# Smoothing patch points ...
# Smoothing iteration 0
# Found 0 non-manifold point(s).
#
# Scaling iteration 0
# Moving mesh using displacement scaling : min:1  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 27
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 1
# Moving mesh using displacement scaling : min:0.75  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 27
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 2
# Moving mesh using displacement scaling : min:0.5625  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 27
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 3
# Moving mesh using displacement scaling : min:0.421875  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 19
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 4
# Moving mesh using displacement scaling : min:0.316406  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 15
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 5
# Displacement scaling for error reduction set to 0.
# Moving mesh using displacement scaling : min:0.237305  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 11
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 6
# Moving mesh using displacement scaling : min:0  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 9
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Successfully moved mesh
#
# Smoothing iteration 1
# Found 0 non-manifold point(s).
#
# Scaling iteration 0
# Moving mesh using displacement scaling : min:1  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 30
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 1
# Moving mesh using displacement scaling : min:0.75  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 27
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 2
# Moving mesh using displacement scaling : min:0.5625  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 27
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 3
# Moving mesh using displacement scaling : min:0.421875  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 23
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 4
# Moving mesh using displacement scaling : min:0.316406  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 23
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 5
# Displacement scaling for error reduction set to 0.
# Moving mesh using displacement scaling : min:0.237305  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 17
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 6
# Moving mesh using displacement scaling : min:0  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 9
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Successfully moved mesh
#
# Smoothing iteration 2
# Found 0 non-manifold point(s).
#
# Scaling iteration 0
# Moving mesh using displacement scaling : min:1  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 29
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 1
# Moving mesh using displacement scaling : min:0.75  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 29
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 2
# Moving mesh using displacement scaling : min:0.5625  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 27
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 3
# Moving mesh using displacement scaling : min:0.421875  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 25
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 4
# Moving mesh using displacement scaling : min:0.316406  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 19
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 5
# Displacement scaling for error reduction set to 0.
# Moving mesh using displacement scaling : min:0.237305  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 15
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Scaling iteration 6
# Moving mesh using displacement scaling : min:0  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 9
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Successfully moved mesh
#
# Patch points smoothed in = 4.77693 s
#
#
#
# Morph iteration 0
# -----------------
# Calculating patchDisplacement as distance to nearest surface point ...
# Wanted displacement : average:0.000244275 min:1.32299e-06 max:0.00275
# Calculated surface displacement in = 0.012367 s
#
#
# Detecting near surfaces ...
# Overriding nearest with intersection of close gaps at 0 out of 50482 points.
# Overriding displacement on features :
#    implicit features    : false
#    explicit features    : true
#    multi-patch features : false
#
# Detected 120 baffle edges out of 100960 edges.
# Initially selected 316 points out of 50482 for reverse attraction.
# Selected 999 points out of 50482 for reverse attraction.
# Stringing feature edges : changed 0 points
# Attraction:
#      linear   : max:(-0.00275 0 1.04083e-17) avg:(-4.51292e-06 7.89487e-07 1.30852e-06)
#      feature  : max:(0 0 0) avg:(0 0 0)
# Feature analysis : total master points:50482 attraction to :
#     feature point   : 0
#     feature edge    : 0
#     nearest surface : 0
#     rest            : 50482
#
# --> FOAM Warning : Displacement (-5.57494e-05 2.61112e-06 -2.92932e-07) at mesh point 9277 coord (0.00104 -0.009 -0.018) points through the surrounding patch faces
# Smoothing displacement ...
# Iteration 0
# Iteration 10
# Iteration 20
# Displacement smoothed in = 0.268024 s
#
#
# Moving mesh ...
#
# Iteration 0
# Moving mesh using displacement scaling : min:1  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 13
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 1
# Moving mesh using displacement scaling : min:0.75  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 11
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 2
# Moving mesh using displacement scaling : min:0.5625  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 9
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Successfully moved mesh
# Moved mesh in = 0.650782 s
#
#
#
# Morph iteration 1
# -----------------
# Calculating patchDisplacement as distance to nearest surface point ...
# Wanted displacement : average:0.000229989 min:1.23799e-07 max:0.00271411
# Calculated surface displacement in = 0.013626 s
#
#
# Detecting near surfaces ...
# Overriding nearest with intersection of close gaps at 0 out of 50482 points.
# Overriding displacement on features :
#    implicit features    : false
#    explicit features    : true
#    multi-patch features : false
#
# Detected 118 baffle edges out of 100960 edges.
# Initially selected 316 points out of 50482 for reverse attraction.
# Selected 999 points out of 50482 for reverse attraction.
# Stringing feature edges : changed 0 points
# Attraction:
#      linear   : max:(-0.00271411 -8.67362e-19 0) avg:(-4.13403e-06 5.87356e-07 1.21774e-06)
#      feature  : max:(0 0 0) avg:(0 0 0)
# Feature analysis : total master points:50482 attraction to :
#     feature point   : 0
#     feature edge    : 0
#     nearest surface : 0
#     rest            : 50482
#
# --> FOAM Warning : Displacement (-0.000113964 1.20277e-05 3.33411e-06) at mesh point 9277 coord (0.00100864 -0.00899853 -0.0180002) points through the surrounding patch faces
# Smoothing displacement ...
# Iteration 0
# Iteration 10
# Iteration 20
# Displacement smoothed in = 0.260004 s
#
#
# Moving mesh ...
#
# Iteration 0
# Moving mesh using displacement scaling : min:1  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 14
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 1
# Moving mesh using displacement scaling : min:0.75  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 10
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 2
# Moving mesh using displacement scaling : min:0.5625  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 10
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 3
# Moving mesh using displacement scaling : min:0.421875  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 10
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 4
# Moving mesh using displacement scaling : min:0.316406  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 10
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 5
# Displacement scaling for error reduction set to 0.
# Moving mesh using displacement scaling : min:0.237305  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 10
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 6
# Moving mesh using displacement scaling : min:0  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 9
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Successfully moved mesh
# Moved mesh in = 1.5691 s
#
#
#
# Morph iteration 2
# -----------------
# Calculating patchDisplacement as distance to nearest surface point ...
# Wanted displacement : average:0.00020408 min:2.5355e-07 max:0.00271411
# Calculated surface displacement in = 0.013428 s
#
#
# Detecting near surfaces ...
# Overriding nearest with intersection of close gaps at 0 out of 50482 points.
# Overriding displacement on features :
#    implicit features    : false
#    explicit features    : true
#    multi-patch features : false
#
# Detected 110 baffle edges out of 100960 edges.
# Initially selected 316 points out of 50482 for reverse attraction.
# Selected 999 points out of 50482 for reverse attraction.
# Stringing feature edges : changed 0 points
# Attraction:
#      linear   : max:(-0.00271411 -8.67362e-19 0) avg:(-3.57642e-06 4.17863e-07 9.44325e-07)
#      feature  : max:(0 0 0) avg:(0 0 0)
# Feature analysis : total master points:50482 attraction to :
#     feature point   : 0
#     feature edge    : 0
#     nearest surface : 0
#     rest            : 50482
#
# --> FOAM Warning : Displacement (-4.70962e-05 1.69257e-05 1.73912e-05) at mesh point 348 coord (-0.000589536 -0.0115597 -0.0175621) points through the surrounding patch faces
# Smoothing displacement ...
# Iteration 0
# Iteration 10
# Iteration 20
# Displacement smoothed in = 0.254731 s
#
#
# Moving mesh ...
#
# Iteration 0
# Moving mesh using displacement scaling : min:1  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 14
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 1
# Moving mesh using displacement scaling : min:0.75  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 10
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 2
# Moving mesh using displacement scaling : min:0.5625  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 8
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Successfully moved mesh
# Moved mesh in = 0.652702 s
#
#
#
# Morph iteration 3
# -----------------
# Calculating patchDisplacement as distance to nearest surface point ...
# Wanted displacement : average:0.000167957 min:1.37804e-07 max:0.00257397
# Calculated surface displacement in = 0.012701 s
#
#
# Detecting near surfaces ...
# Overriding nearest with intersection of close gaps at 0 out of 50482 points.
# Overriding displacement on features :
#    implicit features    : false
#    explicit features    : true
#    multi-patch features : false
#
# Detected 96 baffle edges out of 100960 edges.
# Initially selected 312 points out of 50482 for reverse attraction.
# Selected 996 points out of 50482 for reverse attraction.
# Stringing feature edges : changed 0 points
# Attraction:
#      linear   : max:(-0.00257397 -3.46945e-18 -3.46945e-18) avg:(-2.72641e-06 1.64233e-07 5.883e-07)
#      feature  : max:(0 0 0) avg:(0 0 0)
# Feature analysis : total master points:50482 attraction to :
#     feature point   : 0
#     feature edge    : 0
#     nearest surface : 0
#     rest            : 50482
#
# --> FOAM Warning : Displacement (-5.77436e-06 3.4667e-05 3.65623e-05) at mesh point 348 coord (-0.000633891 -0.0115438 -0.0175458) points through the surrounding patch faces
# Smoothing displacement ...
# Iteration 0
# Iteration 10
# Iteration 20
# Displacement smoothed in = 0.268698 s
#
#
# Moving mesh ...
#
# Iteration 0
# Moving mesh using displacement scaling : min:1  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 14
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 1
# Moving mesh using displacement scaling : min:0.75  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 10
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 2
# Moving mesh using displacement scaling : min:0.5625  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 10
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 3
# Moving mesh using displacement scaling : min:0.421875  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 10
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 4
# Moving mesh using displacement scaling : min:0.316406  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 10
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 5
# Displacement scaling for error reduction set to 0.
# Moving mesh using displacement scaling : min:0.237305  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 10
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
# ...
#     rest            : 50482
#
# --> FOAM Warning : Displacement (1.44602e-06 -1.21223e-06 9.2424e-07) at mesh point 109809 coord (0.00296232 0.025134 -0.00134947) points through the surrounding patch faces
# Smoothing displacement ...
# Iteration 0
# Iteration 10
# Iteration 20
# Displacement smoothed in = 0.278372 s
#
#
# Moving mesh ...
#
# Iteration 0
# Moving mesh using displacement scaling : min:1  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 32
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 2
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 2
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 1
# Moving mesh using displacement scaling : min:0.75  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 32
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 2
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 2
# Moving mesh using displacement scaling : min:0.5625  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 28
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 2
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 3
# Moving mesh using displacement scaling : min:0.421875  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 22
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 4
# Moving mesh using displacement scaling : min:0.316406  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 20
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 5
# Displacement scaling for error reduction set to 0.
# Moving mesh using displacement scaling : min:0.237305  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 18
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 6
# Moving mesh using displacement scaling : min:0  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 10
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 7
# Moving mesh using displacement scaling : min:0  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 8
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Successfully moved mesh
# Moved mesh in = 1.86966 s
#
#
#
# Morph iteration 9
# -----------------
# Calculating patchDisplacement as distance to nearest surface point ...
# Wanted displacement : average:3.4136e-06 min:4.86634e-10 max:0.00257397
# Calculated surface displacement in = 0.013457 s
#
#
# Detecting near surfaces ...
# Overriding nearest with intersection of close gaps at 0 out of 50482 points.
# Overriding displacement on features :
#    implicit features    : false
#    explicit features    : true
#    multi-patch features : false
#
# Detected 42 baffle edges out of 100960 edges.
# Initially selected 312 points out of 50482 for reverse attraction.
# Selected 1000 points out of 50482 for reverse attraction.
# Stringing feature edges : changed 0 points
# Attraction:
#      linear   : max:(-0.00257397 -3.46945e-18 -3.46945e-18) avg:(-7.36498e-07 -3.02665e-08 -2.85442e-08)
#      feature  : max:(0 0 0) avg:(0 0 0)
# Feature analysis : total master points:50482 attraction to :
#     feature point   : 0
#     feature edge    : 0
#     nearest surface : 0
#     rest            : 50482
#
# --> FOAM Warning : Displacement (1.30104e-18 -1.28291e-06 2.55187e-07) at mesh point 109809 coord (0.00296341 0.025133 -0.00134877) points through the surrounding patch faces
# Smoothing displacement ...
# Iteration 0
# Iteration 10
# Iteration 20
# Displacement smoothed in = 0.271766 s
#
#
# Moving mesh ...
#
# Iteration 0
# Moving mesh using displacement scaling : min:1  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 35
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 9
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 2
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 1
# Moving mesh using displacement scaling : min:0.75  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 33
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 4
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 4
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 2
# Moving mesh using displacement scaling : min:0.5625  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 33
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 4
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 3
# Moving mesh using displacement scaling : min:0.421875  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 29
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 4
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 4
# Moving mesh using displacement scaling : min:0.316406  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 19
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 4
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 5
# Displacement scaling for error reduction set to 0.
# Moving mesh using displacement scaling : min:0.237305  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 19
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 4
#     faces on cells with determinant < 0.001                : 0
#
# Iteration 6
# Moving mesh using displacement scaling : min:0  max:1
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 9
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Successfully moved mesh
# Moved mesh in = 1.62938 s
#
#
# Repatching faces according to nearest surface ...
# Repatched 140 faces in = 0.057565 s
#
#
# Edge intersection testing:
#     Number of edges             : 453878
#     Number of edges to retest   : 150992
#     Number of intersected edges : 50437
# Merging 15691 sets of faces.
#
# Edge intersection testing:
#     Number of edges             : 437902
#     Number of edges to retest   : 62780
#     Number of intersected edges : 34455
#
# Undo iteration 0
# ----------------
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 13
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Masters that need to be restored:4
# Edge intersection testing:
#     Number of edges             : 437910
#     Number of edges to retest   : 24
#     Number of intersected edges : 34463
#
#
# Undo iteration 1
# ----------------
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 9
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Masters that need to be restored:0
#
# Merging all points on surface that
# - are used by only two boundary faces and
# - make an angle with a cosine of more than 0.866025.
#
# Removing 15386 straight edge points ...
#
# Edge intersection testing:
#     Number of edges             : 437910
#     Number of edges to retest   : 62126
#     Number of intersected edges : 34459
#
# Undo iteration 0
# ----------------
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 9
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Detected 0 error faces on boundaries that have been merged. These will be restored to their original faces.
#
# Detected 9 error faces in mesh. Restoring neighbours of faces in error.
#
# Edge intersection testing:
#     Number of edges             : 437910
#     Number of edges to retest   : 866
#     Number of intersected edges : 34459
#
# Removing zero-sized patches:
#     bounding type patch at position 0
#
# Snapped mesh : cells:136659  faces:437910  points:165026
# Cells per refinement level:
#     0	1052
#     1	15408
#     2	120199
# Writing mesh to time constant
# Wrote mesh in = 1.5545 s.
# Mesh snapped in = 25.0029 s.
# Checking final mesh ...
# Checking faces in error :
#     non-orthogonality > 65  degrees                        : 9
#     faces with face pyramid volume < 1e-13                 : 0
#     faces with face-decomposition tet quality < 1e-30      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces on cells with determinant < 0.001                : 0
# Finished meshing with 9 illegal faces (concave, zero area or negative cell pyramid volume)
# Finished meshing in = 33.6424 s.
# End

# %% [markdown]
# Since `simpleFoam` is a **Steady-State** solver, the "Time" here actually represents **Iterations**.
#
# **Key Settings we defined:**
# 1.  **`application simpleFoam;`**: Tells OpenFOAM which solver to use.
# 2.  **`endTime 500;`**: The simulation will try to solve the equations 500 times.
# 3.  **`writeInterval 50;`**: Instead of saving only the final result, we save the data every 50 iterations (0, 50, 100...).
#     * *Why?* This allows us to animate the convergence in ParaView to see how the flow develops from a "guess" to the final solution.

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# cat << 'EOF' > system/controlDict
# /*--------------------------------*- C++ -*----------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  v13                                   |
# |   \\  /    A nd           | Website:  openfoam.org                          |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       dictionary;
#     object      controlDict;
# }
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
#
# application     simpleFoam;
#
# startFrom       startTime;
#
# startTime       0;
#
# stopAt          endTime;
#
# endTime         500;    // Run for 500 iterations
#
# deltaT          1;      // Each step is 1 iteration
#
# writeControl    timeStep;
#
# writeInterval   50;     // <--- SAVE DATA EVERY 50 STEPS (Change this if needed)
#
# purgeWrite      0;      // 0 = Keep all files. (Set to 5 to keep only last 5)
#
# writeFormat     ascii;
#
# writePrecision  6;
#
# writeCompression off;
#
# timeFormat      general;
#
# timePrecision   6;
#
# runTimeModifiable true;
#
# // ************************************************************************* //
# EOF

# %% [markdown]
# just defining that we want our fluid to have laminar properties.

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# cat << 'EOF' > constant/turbulenceProperties
# /*--------------------------------*- C++ -*----------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  v13                                   |
# |   \\  /    A nd           | Website:  openfoam.org                          |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       dictionary;
#     object      turbulenceProperties;
# }
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
#
# simulationType  laminar;
#
# // ************************************************************************* //
# EOF

# %% [markdown]
# In the `constant/transportProperties` file, we define the physical properties of the fluid.
#
# Since we are running an incompressible simulation (`simpleFoam`), the solver uses **Kinematic Viscosity** ($\nu$) instead of dynamic viscosity.
#
# **We configured this for Water at 20°C:**
# **Viscosity ($\nu$):** $1 \times 10^{-6} m^2/s$
#     * *Comparison:* Air would be $\approx 1.5 \times 10^{-5}$ (15x more viscous kinematically).
#
# **Understanding the Units:**
# The line `nu [0 2 -1 0 0 0 0]` represents the SI dimensions:
# **Length:** 2 ($m^2$)
# **Time:** -1 ($s^{-1}$)
# * Result: $m^2/s$

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# cat << 'EOF' > constant/transportProperties
# /*--------------------------------*- C++ -*----------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  v13                                   |
# |   \\  /    A nd           | Website:  openfoam.org                          |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       dictionary;
#     object      transportProperties;
# }
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
#
# transportModel  Newtonian;
#
# nu              [0 2 -1 0 0 0 0] 1e-06;
#
# // ************************************************************************* //
# EOF

# %% [markdown]
# the 0 directory contains the initial conditions. The file U specifically tells the solver how the fluid is momving at the start of the simulation and how it behaves at the boundaries.

# %% [markdown]
# We define the flow behavior in the `0/U` file. This is where we apply our physics calculations.
#
# **Boundary Configuration:**
# 1.  **Inlet (`fixedValue`):** We force water into the pipe at a constant speed of **0.078 m/s**.
#     * *Why this speed?* As calculated in the "Theoretical Background," this ensures a Reynolds number of ~250, allowing the flow to fully develop within our 100mm pipe.
# 2.  **Outlet (`zeroGradient`):** We tell the solver "Let the flow leave the pipe without obstruction." The velocity at the outlet is calculated based on what is happening inside.
# 3.  **Walls (`noSlip`):** This is the fundamental rule of fluid mechanics. The fluid touching the wall has **zero velocity** due to friction.
#
# **Internal Field:**
# * We start the simulation assuming the water inside is completely still (`0 0 0`). The solver will then "push" the inlet water in over time.

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# rm 0/k 0/omega 0/nut 0/nuTilda 2>/dev/null
# cat << 'EOF' > 0/U
# /*--------------------------------*- C++ -*----------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  v13                                   |
# |   \\  /    A nd           | Website:  openfoam.org                          |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       volVectorField;
#     object      U;
# }
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
#
# dimensions      [0 1 -1 0 0 0 0];
#
# internalField   uniform (0 0 0);
#
# boundaryField
# {
#     // Fluid enters at 0.04 m/s in X-direction
#     inlet
#     {
#         type            fixedValue;
#         value           uniform (0.04 0 0);
#     }
#
#     // Gradient is zero at outlet (let it flow out)
#     outlet
#     {
#         type            zeroGradient;
#     }
#
#     // No slip at walls (friction)
#     walls
#     {
#         type            noSlip;
#     }
# }
#
# // ************************************************************************* //
# EOF

# %% [markdown]
# We define the pressure field in the `0/p` file.
#
# **Important Note on Units:**
# Since `simpleFoam` is an incompressible solver, it calculates **Kinematic Pressure** ($P / \rho$).
# * **Unit:** $m^2/s^2$ (instead of Pascals).
# * To get Pascals later, simply multiply the result by the fluid density (e.g., $1000 kg/m^3$ for water).
#
# **Boundary Configuration:**
# 1.  **Outlet (`fixedValue` 0):** We set the outlet to **0** (Gauge Pressure). This gives the solver a reference point.
# 2.  **Inlet (`zeroGradient`):** We do **not** set the pressure here. We let the solver calculate how much pressure is required to push the fluid at the requested 0.078 m/s. This resulting value is our **Pressure Drop ($\Delta P$)**.
# 3.  **Walls (`zeroGradient`):** Pressure does not have a "no-slip" condition. It assumes the pressure gradient normal to the wall is zero.

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# cat << 'EOF' > 0/p
# /*--------------------------------*- C++ -*----------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  v13                                   |
# |   \\  /    A nd           | Website:  openfoam.org                          |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       volScalarField;
#     object      p;
# }
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
#
# dimensions      [0 2 -2 0 0 0 0];
#
# internalField   uniform 0;
#
# boundaryField
# {
#     inlet
#     {
#         type            zeroGradient;
#     }
#
#     outlet
#     {
#         type            fixedValue;
#         value           uniform 0;
#     }
#
#     walls
#     {
#         type            zeroGradient;
#     }
# }
#
# // ************************************************************************* //
# EOF

# %% [markdown]
# The file `0/nuTilda` represents the **Modified Turbulent Viscosity**, which is specific to the Spalart-Allmaras turbulence model.
#
# Even though we are running a **Laminar** simulation (where turbulence = 0), we initialize this file to keep our case "Turbulence-Ready."
# * If we later enable turbulence, this file provides the starting values.
# * **Inlet:** Set to `0` (Clean flow, no turbulence entering).
# * **Walls:** Set to `0` (Turbulence dies at the wall).

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# # 1. Fix nuTilda (The one that crashed)
# cat << 'EOF' > 0/nuTilda
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       volScalarField;
#     object      nuTilda;
# }
# dimensions      [0 2 -1 0 0 0 0];
# internalField   uniform 0;
# boundaryField
# {
#     inlet   { type fixedValue; value uniform 0; }
#     outlet  { type zeroGradient; }
#     walls   { type zeroGradient; }
# }
# EOF

# %% [markdown]
# The file `0/k` represents the energy contained in the turbulent eddies of the fluid.
#
# **Why define this for Laminar flow?**
# Similar to `nuTilda`, we include it so If we switch to a turbulence model later, OpenFOAM will look for this file.
#
# * **Physical Meaning:** $k = \frac{3}{2}(U I)^2$, where $I$ is turbulence intensity.
# * **Inlet:** We set a small non-zero value (`0.24`) to represent minute background disturbances, though in a purely Laminar solver, this is ignored.
# * **Walls:** We use a `kqRWallFunction` which is a smart boundary condition. It acts like a "Zero Value" condition but is numerically stable for complex meshes.

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# # 2. Fix k (Turbulent Kinetic Energy)
# cat << 'EOF' > 0/k
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       volScalarField;
#     object      k;
# }
# dimensions      [0 2 -2 0 0 0 0];
# internalField   uniform 0;
# boundaryField
# {
#     inlet   { type fixedValue; value uniform 0; }
#     outlet  { type zeroGradient; }
#     walls   { type zeroGradient; }
# }
# EOF

# %% [markdown]
# The file `0/omega` defines the frequency of turbulence dissipation ($1/s$).
# current simulation is Laminar, including `omega` makes this case compatible with the **$k-\omega$ SST** model. This is the "Gold Standard" turbulence model for engineering because it handles walls much better than $k-\epsilon$.
#
# **Inlet:** Set to a small background value (`0.24`).
# **Walls (`omegaWallFunction`):** This is critical.

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# # 3. Fix omega (Specific Dissipation Rate)
# cat << 'EOF' > 0/omega
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       volScalarField;
#     object      omega;
# }
# dimensions      [0 0 -1 0 0 0 0];
# internalField   uniform 0;
# boundaryField
# {
#     inlet   { type fixedValue; value uniform 0; }
#     outlet  { type zeroGradient; }
#     walls   { type zeroGradient; }
# }
# EOF

# %% [markdown]
# The file `0/epsilon` defines the rate at which turbulent energy decays ($m^2/s^3$).
# This ensures compatibility with the standard **$k-\epsilon$** turbulence model, which is the most common model.
#
# * **$k$ (Energy):** The size/strength of the eddies.
# * **$\epsilon$ (Dissipation):** How fast those eddies break down and disappear.
# * **Relationship:** High $\epsilon$ means turbulence dies out quickly.
#
# **Boundary Configuration:**
# 1.  **Inlet:** Set to a small background value.
# 2.  **Walls (`epsilonWallFunction`):** Similar to `omega`, we use a wall function to approximate the complex behavior of dissipation near the wall without needing an impossibly fine mesh.

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# # 4. Fix epsilon (Dissipation Rate)
# cat << 'EOF' > 0/epsilon
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       volScalarField;
#     object      epsilon;
# }
# dimensions      [0 2 -3 0 0 0 0];
# internalField   uniform 0;
# boundaryField
# {
#     inlet   { type fixedValue; value uniform 0; }
#     outlet  { type zeroGradient; }
#     walls   { type zeroGradient; }
# }
# EOF

# %% [markdown]
# The file `0/nut` defines the **Turbulent Eddy Viscosity** ($\nu_t$).
#
# * **$\nu$ (Kinematic Viscosity):** A real property of the fluid.
# * **$\nu_t$ (Turbulent Viscosity):** A calculated property representing how much the turbulence "mixes" the flow. High $\nu_t$ means the flow is acting like a very thick syrup due to chaotic mixing.
#
# **Boundary Configuration:**
# 1.  **Internal Field:** Initialized to `0` (Laminar).
# 2.  **Walls (`nutkWallFunction`):** This is a standard wall function. It calculates the viscosity near the wall based on the Turbulent Kinetic Energy ($k$).
#     * *Benefit:* It allows us to simulate the boundary layer without needing a mesh that is microscopically fine.

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# # 5. Fix nut (Calculated is actually okay for this one, but let's reset it to be safe)
# cat << 'EOF' > 0/nut
# FoamFile
# {
#     version     2.0;
#     format      ascii;
#     class       volScalarField;
#     object      nut;
# }
# dimensions      [0 2 -1 0 0 0 0];
# internalField   uniform 0;
# boundaryField
# {
#     inlet   { type calculated; value uniform 0; }
#     outlet  { type calculated; value uniform 0; }
#     walls   { type calculated; value uniform 0; }
# }
# EOF

# %% [markdown]
# # execute

# %%
# %%bash
# cd $FOAM_RUN/pipeProject
# simpleFoam
# paraFoam
# Out:
# simpleFoam has been superseded and replaced by the more general
# incompressibleFluid solver module executed by the foamRun application:
#
#     foamRun -solver incompressibleFluid
#
# /*---------------------------------------------------------------------------*\
#   =========                 |
#   \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox
#    \\    /   O peration     | Website:  https://openfoam.org
#     \\  /    A nd           | Version:  13
#      \\/     M anipulation  |
# \*---------------------------------------------------------------------------*/
# Build  : 13-cde978a97c93
# Exec   : foamRun -solver incompressibleFluid
# Date   : Jan 27 2026
# Time   : 20:42:16
# Host   : "Radin"
# PID    : 19200
# I/O    : uncollated
# Case   : /home/radin/OpenFOAM/radin-13/run/pipeProject
# nProcs : 1
# sigFpe : Enabling floating point exception trapping (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 10)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# Create mesh for time = 0
#
# Selecting solver incompressibleFluid
# Selecting viscosity model constant
# Selecting turbulence model type RAS
#     Selecting RAS turbulence model SpalartAllmaras
# No MRF models present
#
#
# SIMPLE: No convergence criteria found
#
#
# SIMPLE: Operating solver in steady-state mode with 1 outer corrector
# SIMPLE: Operating solver in SIMPLE mode
#
#
#
# Starting time loop
#
# Reading surface description:
#     yNormal
#
# streamlines streamlines:
#     automatic track length specified through number of sub cycles : 5
#
# forcesBase forceCoeffs:
# --> FOAM Warning :
#     From function Foam::labelHashSet Foam::polyBoundaryMesh::patchSet(const Foam::UList<Foam::wordRe>&, bool, bool) const
#     in file meshes/polyMesh/polyBoundaryMesh/polyBoundaryMesh.C at line 814
#     Cannot find any patch or group names matching "motorBike.*"
# --> FOAM Warning :
#     From function Foam::labelHashSet Foam::polyBoundaryMesh::patchSet(const Foam::dictionary&, bool) const
#     in file meshes/polyMesh/polyBoundaryMesh/polyBoundaryMesh.C at line 863
#     Cannot find any patch named 1("motorBike.*")
# Valid patch names are
# 3
# (
# inlet
# outlet
# walls
# )
#
#     Not including porosity effects
# forces forceCoeffs:
# --> FOAM Warning :
#     From function Foam::labelHashSet Foam::polyBoundaryMesh::patchSet(const Foam::UList<Foam::wordRe>&, bool, bool) const
#     in file meshes/polyMesh/polyBoundaryMesh/polyBoundaryMesh.C at line 814
#     Cannot find any patch or group names matching "motorBike.*"
# --> FOAM Warning :
#     From function Foam::labelHashSet Foam::polyBoundaryMesh::patchSet(const Foam::dictionary&, bool) const
#     in file meshes/polyMesh/polyBoundaryMesh/polyBoundaryMesh.C at line 863
#     Cannot find any patch named 1("motorBike.*")
# Valid patch names are
# 3
# (
# inlet
# outlet
# walls
# )
#
#     Not including porosity effects
# forceCoeffs forceCoeffs:
# --> FOAM Warning :
#     From function Foam::labelHashSet Foam::polyBoundaryMesh::patchSet(const Foam::UList<Foam::wordRe>&, bool, bool) const
#     in file meshes/polyMesh/polyBoundaryMesh/polyBoundaryMesh.C at line 814
#     Cannot find any patch or group names matching "motorBike.*"
# --> FOAM Warning :
#     From function Foam::labelHashSet Foam::polyBoundaryMesh::patchSet(const Foam::dictionary&, bool) const
#     in file meshes/polyMesh/polyBoundaryMesh/polyBoundaryMesh.C at line 863
#     Cannot find any patch named 1("motorBike.*")
# Valid patch names are
# 3
# (
# inlet
# outlet
# walls
# )
#
#     Not including porosity effects
# streamlines streamlines write:
#     Seeded 0 particles
#     Sampled 0 locations
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 1s
#
# smoothSolver:  Solving for Ux, Initial residual = 1, Final residual = 0.024164, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 1, Final residual = 0.0152872, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 1, Final residual = 0.0152865, No Iterations 2
# GAMG:  Solving for p, Initial residual = 1, Final residual = 0.0530651, No Iterations 10
# time step continuity errors : sum local = 0.00203147, global = -0.000365789, cumulative = -0.000365789
# Selecting patchDistMethod meshWave
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 1.0997 s  ClockTime = 1 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 2s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.33808, Final residual = 0.0238885, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.301298, Final residual = 0.0208079, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.301305, Final residual = 0.0208095, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.402681, Final residual = 0.0400494, No Iterations 3
# time step continuity errors : sum local = 0.067049, global = 0.0131468, cumulative = 0.012781
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 1.32197 s  ClockTime = 1 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 3s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.414873, Final residual = 0.0266648, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.215325, Final residual = 0.0146986, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.232909, Final residual = 0.0157996, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.282478, Final residual = 0.0128077, No Iterations 3
# time step continuity errors : sum local = 0.0443145, global = -0.00118296, cumulative = 0.011598
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 1.55191 s  ClockTime = 1 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 4s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.284601, Final residual = 0.0174771, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.174836, Final residual = 0.0087363, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.137462, Final residual = 0.00642707, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.169568, Final residual = 0.0154681, No Iterations 2
# time step continuity errors : sum local = 0.0596208, global = 0.012902, cumulative = 0.0245001
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 1.76213 s  ClockTime = 2 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 5s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.177306, Final residual = 0.010579, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.472966, Final residual = 0.0271242, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.453904, Final residual = 0.0259797, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.121619, Final residual = 0.00662392, No Iterations 4
# time step continuity errors : sum local = 0.0199634, global = 0.00425893, cumulative = 0.028759
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 1.97738 s  ClockTime = 2 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 6s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.101154, Final residual = 0.00598498, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.490751, Final residual = 0.0284741, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.536748, Final residual = 0.0309366, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.335996, Final residual = 0.0309589, No Iterations 3
# time step continuity errors : sum local = 0.0579749, global = -0.0123011, cumulative = 0.0164579
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 2.1969 s  ClockTime = 2 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 7s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0842721, Final residual = 0.00495503, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.239698, Final residual = 0.014298, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.294119, Final residual = 0.0172655, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.566703, Final residual = 0.0255622, No Iterations 3
# time step continuity errors : sum local = 0.0365564, global = 0.00340228, cumulative = 0.0198602
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 2.40537 s  ClockTime = 2 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 8s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0750499, Final residual = 0.00421664, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.119459, Final residual = 0.00592234, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.123697, Final residual = 0.00682093, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.4393, Final residual = 0.0182022, No Iterations 3
# time step continuity errors : sum local = 0.0325538, global = 0.00280719, cumulative = 0.0226674
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 2.61543 s  ClockTime = 3 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 9s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0698728, Final residual = 0.00371372, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.26556, Final residual = 0.0137433, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.228984, Final residual = 0.0116681, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.380394, Final residual = 0.0144556, No Iterations 3
# time step continuity errors : sum local = 0.0242449, global = 0.00188854, cumulative = 0.0245559
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 2.83036 s  ClockTime = 3 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 10s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0831813, Final residual = 0.00457455, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.336051, Final residual = 0.0188738, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.344032, Final residual = 0.0192374, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.404585, Final residual = 0.0402948, No Iterations 2
# time step continuity errors : sum local = 0.0595058, global = 0.00721934, cumulative = 0.0317752
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 3.0411 s  ClockTime = 3 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 11s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0990027, Final residual = 0.00562652, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.273126, Final residual = 0.0159929, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.320335, Final residual = 0.0186668, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.455547, Final residual = 0.0182206, No Iterations 3
# time step continuity errors : sum local = 0.0228649, global = -0.00199848, cumulative = 0.0297768
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 3.29834 s  ClockTime = 3 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 12s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.1025, Final residual = 0.00595143, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.218511, Final residual = 0.0129215, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.248797, Final residual = 0.0147037, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.463498, Final residual = 0.0204131, No Iterations 3
# time step continuity errors : sum local = 0.0215964, global = -0.00186541, cumulative = 0.0279113
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 3.51277 s  ClockTime = 3 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 13s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0949806, Final residual = 0.00549027, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.259459, Final residual = 0.0148984, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.2567, Final residual = 0.0148522, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.547838, Final residual = 0.0243967, No Iterations 3
# time step continuity errors : sum local = 0.0183642, global = -0.00222795, cumulative = 0.0256834
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 3.75416 s  ClockTime = 4 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 14s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0834994, Final residual = 0.00485149, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.276135, Final residual = 0.015795, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.276408, Final residual = 0.0158769, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.458193, Final residual = 0.0223709, No Iterations 3
# time step continuity errors : sum local = 0.0196332, global = 0.00358272, cumulative = 0.0292661
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 3.95635 s  ClockTime = 4 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 15s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0700088, Final residual = 0.00408646, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.218866, Final residual = 0.0125661, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.23662, Final residual = 0.0136086, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.437581, Final residual = 0.021607, No Iterations 3
# time step continuity errors : sum local = 0.0200208, global = 0.00300145, cumulative = 0.0322676
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 4.25497 s  ClockTime = 4 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 16s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0590228, Final residual = 0.00335955, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.174098, Final residual = 0.00978625, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.187217, Final residual = 0.0105467, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.419989, Final residual = 0.0180291, No Iterations 3
# time step continuity errors : sum local = 0.0166409, global = 0.00111397, cumulative = 0.0333815
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 4.47361 s  ClockTime = 4 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 17s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0569272, Final residual = 0.00317954, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.173203, Final residual = 0.00936872, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.175583, Final residual = 0.00957234, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.413453, Final residual = 0.0221319, No Iterations 3
# time step continuity errors : sum local = 0.0197869, global = -0.00273503, cumulative = 0.0306465
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 4.69802 s  ClockTime = 5 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 18s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0561778, Final residual = 0.00316426, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.220156, Final residual = 0.0119659, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.215023, Final residual = 0.0117438, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.384333, Final residual = 0.014746, No Iterations 3
# time step continuity errors : sum local = 0.0124961, global = -0.000932079, cumulative = 0.0297144
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 4.93044 s  ClockTime = 5 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 19s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0538392, Final residual = 0.00302778, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.253671, Final residual = 0.0139235, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.256833, Final residual = 0.0141243, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.42412, Final residual = 0.0408618, No Iterations 2
# time step continuity errors : sum local = 0.0288476, global = -9.47389e-05, cumulative = 0.0296197
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 5.13591 s  ClockTime = 5 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 20s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0503821, Final residual = 0.00284307, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.24597, Final residual = 0.0135737, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.2564, Final residual = 0.0142184, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.478992, Final residual = 0.0194008, No Iterations 3
# time step continuity errors : sum local = 0.0113052, global = -0.00108617, cumulative = 0.0285335
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 5.35979 s  ClockTime = 5 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 21s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0437173, Final residual = 0.00246813, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.239213, Final residual = 0.0133583, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.255346, Final residual = 0.0142416, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.536484, Final residual = 0.0214829, No Iterations 3
# time step continuity errors : sum local = 0.0101761, global = 0.000850091, cumulative = 0.0293836
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 5.57724 s  ClockTime = 6 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 22s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0356445, Final residual = 0.00202564, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.231903, Final residual = 0.0128706, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.235676, Final residual = 0.0131187, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.538682, Final residual = 0.0252787, No Iterations 3
# time step continuity errors : sum local = 0.0111759, global = 0.000879837, cumulative = 0.0302634
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 5.80628 s  ClockTime = 6 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 23s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.028806, Final residual = 0.00162289, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.201568, Final residual = 0.0109671, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.198271, Final residual = 0.0108651, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.549375, Final residual = 0.027719, No Iterations 3
# time step continuity errors : sum local = 0.0117257, global = 0.000554012, cumulative = 0.0308175
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 6.02646 s  ClockTime = 6 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 24s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0275707, Final residual = 0.00153973, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.18108, Final residual = 0.00974508, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.177308, Final residual = 0.0095664, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.563168, Final residual = 0.0276679, No Iterations 3
# time step continuity errors : sum local = 0.0111488, global = 0.000318294, cumulative = 0.0311358
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 6.26503 s  ClockTime = 6 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 25s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0295379, Final residual = 0.00165061, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.192475, Final residual = 0.0105751, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.196646, Final residual = 0.0107691, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.57122, Final residual = 0.0529539, No Iterations 2
# time step continuity errors : sum local = 0.0196202, global = 0.00127137, cumulative = 0.0324071
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 6.48597 s  ClockTime = 6 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 26s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0296581, Final residual = 0.00165429, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.222, Final residual = 0.0124025, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.235521, Final residual = 0.0131203, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.560112, Final residual = 0.0530002, No Iterations 2
# time step continuity errors : sum local = 0.0177265, global = 0.00169404, cumulative = 0.0341012
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 6.6932 s  ClockTime = 7 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 27s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0286057, Final residual = 0.00161437, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.233335, Final residual = 0.0130604, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.244072, Final residual = 0.0136648, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.483409, Final residual = 0.0177795, No Iterations 3
# time step continuity errors : sum local = 0.00627149, global = -0.000888048, cumulative = 0.0332131
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 6.92342 s  ClockTime = 7 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 28s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0266016, Final residual = 0.00149794, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.224047, Final residual = 0.0123154, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.229734, Final residual = 0.0126851, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.444165, Final residual = 0.0178994, No Iterations 3
# time step continuity errors : sum local = 0.00632274, global = -0.000261678, cumulative = 0.0329514
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 7.15013 s  ClockTime = 7 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 29s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0236369, Final residual = 0.00133111, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.202287, Final residual = 0.0110712, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.208644, Final residual = 0.0115052, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.415776, Final residual = 0.0166889, No Iterations 3
# time step continuity errors : sum local = 0.00601461, global = 0.000369297, cumulative = 0.0333207
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 7.36436 s  ClockTime = 7 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 30s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0201884, Final residual = 0.00112844, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.177135, Final residual = 0.00955635, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.187209, Final residual = 0.0101598, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.38956, Final residual = 0.015535, No Iterations 3
# time step continuity errors : sum local = 0.00569762, global = 0.000444997, cumulative = 0.0337657
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 7.59024 s  ClockTime = 8 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 31s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0185864, Final residual = 0.00104012, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.172062, Final residual = 0.00922574, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.183877, Final residual = 0.00998278, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.365848, Final residual = 0.0137796, No Iterations 3
# time step continuity errors : sum local = 0.00512583, global = 0.000527978, cumulative = 0.0342937
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 7.8283 s  ClockTime = 8 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 32s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0184491, Final residual = 0.00104228, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.180927, Final residual = 0.0098037, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.189599, Final residual = 0.0103035, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.345832, Final residual = 0.0329114, No Iterations 2
# time step continuity errors : sum local = 0.0122295, global = -0.000331219, cumulative = 0.0339625
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 8.03424 s  ClockTime = 8 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 33s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0174622, Final residual = 0.000992261, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.185391, Final residual = 0.0101595, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.19906, Final residual = 0.0109275, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.340788, Final residual = 0.0326482, No Iterations 2
# time step continuity errors : sum local = 0.0112993, global = -0.000349819, cumulative = 0.0336127
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 8.26044 s  ClockTime = 8 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 34s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0168592, Final residual = 0.000959915, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.190391, Final residual = 0.0104226, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.201191, Final residual = 0.0110425, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.345739, Final residual = 0.0336094, No Iterations 2
# time step continuity errors : sum local = 0.0105105, global = -0.000359865, cumulative = 0.0332528
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 8.46872 s  ClockTime = 8 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 35s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.016002, Final residual = 0.000910099, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.189893, Final residual = 0.0103502, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.197893, Final residual = 0.01084, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.360602, Final residual = 0.0358166, No Iterations 2
# time step continuity errors : sum local = 0.00992091, global = -1.87663e-05, cumulative = 0.033234
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 8.68938 s  ClockTime = 9 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 36s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0140432, Final residual = 0.000798072, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.182511, Final residual = 0.00990548, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.193056, Final residual = 0.0105398, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.373602, Final residual = 0.0160121, No Iterations 3
# time step continuity errors : sum local = 0.00403183, global = 0.000111043, cumulative = 0.0333451
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 8.91211 s  ClockTime = 9 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 37s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0122543, Final residual = 0.000693781, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.174913, Final residual = 0.00939915, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.184619, Final residual = 0.0100031, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.399384, Final residual = 0.0159812, No Iterations 3
# time step continuity errors : sum local = 0.00359568, global = -7.2426e-05, cumulative = 0.0332727
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 9.12912 s  ClockTime = 9 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 38s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0114628, Final residual = 0.000644055, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.169173, Final residual = 0.00896607, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.165045, Final residual = 0.00880274, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.426893, Final residual = 0.0415048, No Iterations 2
# time step continuity errors : sum local = 0.00844058, global = -6.85891e-05, cumulative = 0.0332041
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 9.35169 s  ClockTime = 9 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 39s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0108167, Final residual = 0.000603841, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.161841, Final residual = 0.00873045, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.162067, Final residual = 0.00881388, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.433579, Final residual = 0.0429697, No Iterations 2
# time step continuity errors : sum local = 0.00812449, global = 0.000187352, cumulative = 0.0333914
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 9.55957 s  ClockTime = 10 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 40s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0103012, Final residual = 0.000576659, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.157621, Final residual = 0.00856412, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.164997, Final residual = 0.00898387, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.4056, Final residual = 0.0399084, No Iterations 2
# time step continuity errors : sum local = 0.00753642, global = 0.000216284, cumulative = 0.0336077
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 9.78161 s  ClockTime = 10 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 41s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00997348, Final residual = 0.000560521, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.161381, Final residual = 0.00873272, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.168639, Final residual = 0.00913838, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.36456, Final residual = 0.0355324, No Iterations 2
# time step continuity errors : sum local = 0.00691324, global = 0.000222566, cumulative = 0.0338303
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 10.0061 s  ClockTime = 10 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 42s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00972164, Final residual = 0.000548669, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.163729, Final residual = 0.00883951, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.168032, Final residual = 0.00911689, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.322821, Final residual = 0.0300247, No Iterations 2
# time step continuity errors : sum local = 0.00613539, global = -0.000101775, cumulative = 0.0337285
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 10.2237 s  ClockTime = 10 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 43s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00917265, Final residual = 0.000521016, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.158633, Final residual = 0.00854813, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.164758, Final residual = 0.00895808, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.297465, Final residual = 0.0293312, No Iterations 2
# time step continuity errors : sum local = 0.00610742, global = -0.000104348, cumulative = 0.0336241
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 10.4433 s  ClockTime = 10 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 44s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00831861, Final residual = 0.000473064, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.149062, Final residual = 0.00805116, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.158685, Final residual = 0.00863783, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.278611, Final residual = 0.0116812, No Iterations 3
# time step continuity errors : sum local = 0.00249806, global = -7.90575e-05, cumulative = 0.0335451
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 10.6634 s  ClockTime = 11 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 45s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00755597, Final residual = 0.00042711, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.147911, Final residual = 0.00790912, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.156661, Final residual = 0.00846873, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.254246, Final residual = 0.0245986, No Iterations 2
# time step continuity errors : sum local = 0.00542803, global = -3.71518e-05, cumulative = 0.0335079
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 10.8847 s  ClockTime = 11 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 46s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00694813, Final residual = 0.000395085, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.148394, Final residual = 0.00797263, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.152826, Final residual = 0.00827376, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.238955, Final residual = 0.022735, No Iterations 2
# time step continuity errors : sum local = 0.00506467, global = 4.53067e-05, cumulative = 0.0335532
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 11.1034 s  ClockTime = 11 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 47s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00671913, Final residual = 0.000385832, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.143965, Final residual = 0.00775479, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.148753, Final residual = 0.00805479, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.225309, Final residual = 0.0210127, No Iterations 2
# time step continuity errors : sum local = 0.00468147, global = 0.000129808, cumulative = 0.033683
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 11.3107 s  ClockTime = 11 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 48s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00653868, Final residual = 0.000376539, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.140729, Final residual = 0.00756102, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.144582, Final residual = 0.00778536, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.211525, Final residual = 0.00724708, No Iterations 3
# time step continuity errors : sum local = 0.00159537, global = 0.000193312, cumulative = 0.0338764
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 11.5411 s  ClockTime = 12 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 49s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00621534, Final residual = 0.000356324, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.141477, Final residual = 0.00752591, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.145598, Final residual = 0.00777586, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.206937, Final residual = 0.0198619, No Iterations 2
# time step continuity errors : sum local = 0.00411942, global = -3.86064e-05, cumulative = 0.0338378
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 11.7503 s  ClockTime = 12 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 50s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00583363, Final residual = 0.000332959, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.133956, Final residual = 0.00715961, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.143711, Final residual = 0.00774174, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.210429, Final residual = 0.0203813, No Iterations 2
# time step continuity errors : sum local = 0.00393165, global = -8.78506e-05, cumulative = 0.0337499
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 12.1464 s  ClockTime = 12 s
#
# streamlines streamlines write:
#     Seeded 0 particles
#     Sampled 0 locations
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 51s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00552748, Final residual = 0.000315145, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.122941, Final residual = 0.00659344, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.135929, Final residual = 0.00736386, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.220054, Final residual = 0.020347, No Iterations 2
# time step continuity errors : sum local = 0.00363435, global = 3.47494e-05, cumulative = 0.0337847
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 12.3776 s  ClockTime = 12 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 52s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00492775, Final residual = 0.000279354, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.116578, Final residual = 0.00626259, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.128595, Final residual = 0.00695961, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.220652, Final residual = 0.0210838, No Iterations 2
# time step continuity errors : sum local = 0.00358087, global = -4.52877e-05, cumulative = 0.0337394
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 12.5909 s  ClockTime = 13 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 53s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00446293, Final residual = 0.000251469, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.117015, Final residual = 0.00627597, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.127295, Final residual = 0.00686932, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.219444, Final residual = 0.0207156, No Iterations 2
# time step continuity errors : sum local = 0.00335929, global = -7.16059e-05, cumulative = 0.0336678
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 12.8515 s  ClockTime = 13 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 54s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00418056, Final residual = 0.000233913, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.118512, Final residual = 0.00636129, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.125102, Final residual = 0.00674219, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.215261, Final residual = 0.0198948, No Iterations 2
# time step continuity errors : sum local = 0.00310373, global = -0.000102752, cumulative = 0.033565
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 13.0584 s  ClockTime = 13 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 55s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00403454, Final residual = 0.00022582, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.119975, Final residual = 0.00644097, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.120207, Final residual = 0.00647141, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.206678, Final residual = 0.00739315, No Iterations 3
# time step continuity errors : sum local = 0.00112051, global = -0.000135003, cumulative = 0.03343
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 13.2843 s  ClockTime = 13 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 56s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00385878, Final residual = 0.000216986, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.119976, Final residual = 0.00639712, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.117494, Final residual = 0.00625971, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.189722, Final residual = 0.0183707, No Iterations 2
# time step continuity errors : sum local = 0.00282154, global = 4.3097e-05, cumulative = 0.0334731
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 13.4955 s  ClockTime = 13 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 57s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00378525, Final residual = 0.000214715, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.112194, Final residual = 0.00601784, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.115144, Final residual = 0.0061809, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.176006, Final residual = 0.0149677, No Iterations 2
# time step continuity errors : sum local = 0.00234234, global = -9.66922e-05, cumulative = 0.0333764
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 13.7239 s  ClockTime = 14 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 58s
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00352645, Final residual = 0.000200737, No Iterations 2
# smoothSolver:  Solving for Uy, Initial residual = 0.10225, Final residual = 0.0055187, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 0.110186, Final residual = 0.00596549, No Iterations 2
# GAMG:  Solving for p, Initial residual = 0.163803, Final residual = 0.014245, No Iterations 2
# time step continuity errors : sum local = 0.00222373, global = -7.88439e-05, cumulative = 0.0332976
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 13.9477 s  ClockTime = 14 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 59s
#
# ...
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 481s
#
# smoothSolver:  Solving for Ux, Initial residual = 7.50168e-09, Final residual = 7.50168e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 5.73935e-08, Final residual = 3.04929e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 4.2242e-08, Final residual = 2.63642e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 5.65131e-08, Final residual = 5.65131e-08, No Iterations 0
# time step continuity errors : sum local = 8.12454e-09, global = -5.10256e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 108.127 s  ClockTime = 108 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 482s
#
# smoothSolver:  Solving for Ux, Initial residual = 7.40556e-09, Final residual = 7.40556e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 5.42553e-08, Final residual = 2.93245e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 4.03831e-08, Final residual = 2.5556e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 6.10054e-08, Final residual = 6.10054e-08, No Iterations 0
# time step continuity errors : sum local = 8.77037e-09, global = -5.67987e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 108.35 s  ClockTime = 108 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 483s
#
# smoothSolver:  Solving for Ux, Initial residual = 7.31095e-09, Final residual = 7.31095e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 5.16833e-08, Final residual = 2.83188e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 3.88472e-08, Final residual = 2.47371e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 7.04867e-08, Final residual = 7.04867e-08, No Iterations 0
# time step continuity errors : sum local = 1.01334e-08, global = -6.2896e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 108.553 s  ClockTime = 109 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 484s
#
# smoothSolver:  Solving for Ux, Initial residual = 7.21774e-09, Final residual = 7.21774e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 4.94598e-08, Final residual = 2.74082e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 3.74592e-08, Final residual = 9.84343e-09, No Iterations 1
# GAMG:  Solving for p, Initial residual = 8.16367e-08, Final residual = 8.16367e-08, No Iterations 0
# time step continuity errors : sum local = 1.17364e-08, global = -6.92313e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 108.765 s  ClockTime = 109 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 485s
#
# smoothSolver:  Solving for Ux, Initial residual = 7.12557e-09, Final residual = 7.12557e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 4.75085e-08, Final residual = 2.6548e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 3.63118e-08, Final residual = 9.55979e-09, No Iterations 1
# GAMG:  Solving for p, Initial residual = 9.33077e-08, Final residual = 9.33077e-08, No Iterations 0
# time step continuity errors : sum local = 1.34143e-08, global = -7.57284e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 108.974 s  ClockTime = 109 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 486s
#
# smoothSolver:  Solving for Ux, Initial residual = 7.03443e-09, Final residual = 7.03443e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 4.57681e-08, Final residual = 2.57277e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 3.52125e-08, Final residual = 9.27597e-09, No Iterations 1
# GAMG:  Solving for p, Initial residual = 1.04998e-07, Final residual = 1.28376e-08, No Iterations 1
# time step continuity errors : sum local = 1.84559e-09, global = -6.29093e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 109.218 s  ClockTime = 109 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 487s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.9502e-09, Final residual = 6.9502e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 7.41975e-08, Final residual = 3.5822e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 4.7966e-08, Final residual = 2.78105e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 5.73648e-08, Final residual = 5.73648e-08, No Iterations 0
# time step continuity errors : sum local = 8.24698e-09, global = -7.78952e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 109.433 s  ClockTime = 109 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 488s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.85914e-09, Final residual = 6.85914e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 7.06166e-08, Final residual = 3.51515e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 4.57384e-08, Final residual = 2.71779e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 4.88636e-08, Final residual = 4.88636e-08, No Iterations 0
# time step continuity errors : sum local = 7.02482e-09, global = -7.93764e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 109.645 s  ClockTime = 110 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 489s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.7721e-09, Final residual = 6.7721e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 6.76245e-08, Final residual = 3.43136e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 4.40726e-08, Final residual = 2.65311e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 5.51562e-08, Final residual = 5.51562e-08, No Iterations 0
# time step continuity errors : sum local = 7.92947e-09, global = -8.08854e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 109.873 s  ClockTime = 110 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 490s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.6887e-09, Final residual = 6.6887e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 6.49622e-08, Final residual = 3.33774e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 4.26381e-08, Final residual = 2.58631e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 6.90003e-08, Final residual = 6.90003e-08, No Iterations 0
# time step continuity errors : sum local = 9.91974e-09, global = -8.23785e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 110.082 s  ClockTime = 110 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 491s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.60812e-09, Final residual = 6.60812e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 6.25277e-08, Final residual = 3.23802e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 4.13035e-08, Final residual = 2.51785e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 8.47011e-08, Final residual = 8.47011e-08, No Iterations 0
# time step continuity errors : sum local = 1.21769e-08, global = -8.38313e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 110.305 s  ClockTime = 110 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 492s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.52991e-09, Final residual = 6.52991e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 6.02413e-08, Final residual = 3.13531e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 4.00296e-08, Final residual = 2.44862e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 1.00577e-07, Final residual = 1.15617e-08, No Iterations 1
# time step continuity errors : sum local = 1.66216e-09, global = -6.73415e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 110.534 s  ClockTime = 111 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 493s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.45315e-09, Final residual = 6.45315e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 6.2961e-08, Final residual = 3.41837e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 4.1497e-08, Final residual = 2.45586e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 5.59646e-08, Final residual = 5.59646e-08, No Iterations 0
# time step continuity errors : sum local = 8.04569e-09, global = -7.74984e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 110.741 s  ClockTime = 111 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 494s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.37012e-09, Final residual = 6.37012e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 5.97162e-08, Final residual = 3.34071e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 3.9461e-08, Final residual = 9.98796e-09, No Iterations 1
# GAMG:  Solving for p, Initial residual = 4.61666e-08, Final residual = 4.61666e-08, No Iterations 0
# time step continuity errors : sum local = 6.63708e-09, global = -7.52653e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 110.968 s  ClockTime = 111 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 495s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.29551e-09, Final residual = 6.29551e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 5.69976e-08, Final residual = 3.25486e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 3.80198e-08, Final residual = 9.70656e-09, No Iterations 1
# GAMG:  Solving for p, Initial residual = 4.66268e-08, Final residual = 4.66268e-08, No Iterations 0
# time step continuity errors : sum local = 6.70324e-09, global = -7.31245e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 111.177 s  ClockTime = 111 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 496s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.22356e-09, Final residual = 6.22356e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 5.45705e-08, Final residual = 3.16511e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 3.67561e-08, Final residual = 9.43215e-09, No Iterations 1
# GAMG:  Solving for p, Initial residual = 5.45348e-08, Final residual = 5.45348e-08, No Iterations 0
# time step continuity errors : sum local = 7.84012e-09, global = -7.10098e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 111.384 s  ClockTime = 111 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 497s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.15329e-09, Final residual = 6.15329e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 5.23673e-08, Final residual = 3.07394e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 3.56045e-08, Final residual = 9.16578e-09, No Iterations 1
# GAMG:  Solving for p, Initial residual = 6.55046e-08, Final residual = 6.55046e-08, No Iterations 0
# time step continuity errors : sum local = 9.41719e-09, global = -6.88735e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 111.61 s  ClockTime = 112 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 498s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.08442e-09, Final residual = 6.08442e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 5.03198e-08, Final residual = 2.98276e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 3.45165e-08, Final residual = 8.90792e-09, No Iterations 1
# GAMG:  Solving for p, Initial residual = 7.72834e-08, Final residual = 7.72834e-08, No Iterations 0
# time step continuity errors : sum local = 1.11106e-08, global = -6.66742e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 111.814 s  ClockTime = 112 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 499s
#
# smoothSolver:  Solving for Ux, Initial residual = 6.01665e-09, Final residual = 6.01665e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 4.84017e-08, Final residual = 2.89263e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 3.34887e-08, Final residual = 8.65763e-09, No Iterations 1
# GAMG:  Solving for p, Initial residual = 8.90874e-08, Final residual = 8.90874e-08, No Iterations 0
# time step continuity errors : sum local = 1.28075e-08, global = -6.43738e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 112.035 s  ClockTime = 112 s
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# Time = 500s
#
# smoothSolver:  Solving for Ux, Initial residual = 5.95002e-09, Final residual = 5.95002e-09, No Iterations 0
# smoothSolver:  Solving for Uy, Initial residual = 4.66029e-08, Final residual = 2.8042e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 3.25071e-08, Final residual = 8.41367e-09, No Iterations 1
# GAMG:  Solving for p, Initial residual = 1.0063e-07, Final residual = 1.218e-08, No Iterations 1
# time step continuity errors : sum local = 1.75105e-09, global = -5.39705e-11, cumulative = 0.033423
# smoothSolver:  Solving for nuTilda, Initial residual = 0, Final residual = 0, No Iterations 0
# ExecutionTime = 112.463 s  ClockTime = 113 s
#
# streamlines streamlines write:
#     Seeded 0 particles
#     Sampled 0 locations
#
# forceCoeffs forceCoeffs write:
#     Cm    = 0
#     Cd    = 0
#     Cl    = 0
#     Cl(f) = 0
#     Cl(r) = 0
#
# End
#
# Created temporary 'pipeProject.OpenFOAM'
# QStandardPaths: wrong permissions on runtime directory /run/user/1000/, 0755 instead of 0700
# I/O    : uncollated
